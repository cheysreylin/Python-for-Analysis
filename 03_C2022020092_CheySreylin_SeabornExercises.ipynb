# %% [markdown]
# # Seaborn Excercises (all required)

# %% [markdown]
# Naming convention for Jupyter Notebook file :
# - WeekNumber_StudentID_StudentName_ExcerciseTitle
# - For example : 03_C2022020091_BornPheakdey_Seaborn_Excersie
#
# Submit to : https://forms.gle/vFY7ziZ7mKiNERhF9

# %% [markdown]
# ### 0. Import Pyplot, Seaborn and Pandas library

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# ### 1. Load dataset 'mpg' from Seaborn into a DataFrame

# %%
df_mpg = sns.load_dataset('mpg')
display(df_mpg.head(5))
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# ### 2. Using data form question #1, ceate a scatter plot that shows a relationship between 'horsepower' and 'mpg'

# %%
sns.scatterplot(data = df_mpg, x = "horsepower", y= "mpg")

# %% [markdown]
# ### 3. Using data form question #1, ceate a scatters plot that shows a relationship between 'horsepower' and 'mpg' for different 'cylinders'(cylinders : color ).

# %%
sns.scatterplot(data = df_mpg, x = "horsepower", y = "mpg", hue = "cylinders")

# %% [markdown]
# ### 4. Using data form question #1, create a scatter plot that shows a relationship between 'model_year' on x axes and 'mgp' on the y axes.

# %%
sns.scatterplot(data = df_mpg, x = 'model_year', y = 'mpg')

# %% [markdown]
# ### 5. Using data form question #1, create a scatter plot that shows a relationship between 'model_year' on x axes and 'mgp' on the y axes for different 'origin'.

# %%
sns.scatterplot(data= df_mpg, x = "model_year", y = "mpg", hue = "origin")

# %% [markdown]
# ### 6. Using data form question #1, create a histogram for 'cylinders'.

# %%
sns.displot(df_mpg.cylinders)

# %%
sns.histplot(data = df_mpg.cylinders)

# %% [markdown]
# ### 7. Using the the plot from question #2 to #6, write a short analytic report describing the important findings in those charts. Report must be at least 50 words. ( Imagine that you are a data analyst writing a report for your company )

# %% [markdown]
# # 2: A short analytic report describing the important findings in this charts
# In this graph, I use scatter plots in seaborn to illustrate the relationship between two variables which are “horsepower”, and “mpg”. In this case “mpg” or miles per gallon, is the distance used to measure in miles that a car can travel per gallon of fuel. And as for the “horsepower” is the major factor in a vehicle’s fuel consumption. We plot each the data points of attributes in an x,y coordinate system where each point represents the observation of the dataset. After plotting, we can observe that whenever the value of horsepower increases, the value of mpg will decrease too. If the value of horsepower decreases, then the value of mpg will increase.
#
#
# # 6: A short analytic report describing the important findings in this charts
# To plot this graph, I used the displot technique in seaborn to create a history for “cylinders” columns. “Cylinders ” refers to the number of engine cylinders (multi-valued discrete variables). This basically helps us to easily see the frequency distribution of this specific column. If you look at the graph, you can see that the highest distribution of this graph is between 4 to 4.5 and it is equal to 200 of the y-axis.

# %% [markdown]
# ### 8. Using data form question #1, create a plot that answer the question below.
# ### Does having more 'weight' result in lower or higher 'mpg' ?

# %%
sns.jointplot(data = df_mpg, x = "weight", y = "mpg")

# %% [markdown]
# # Explain
# => Within this graph, we can say that having more "weight" result in lower "mpg"

# %% [markdown]
# ### 9. Show plots from question #2 and #4 side by side.

# %%
fig, axes = plt.subplots(1,2, figsize = (15,5))
sns.scatterplot(ax= axes[0], data = df_mpg, x = "horsepower", y= "mpg") 
sns.scatterplot(ax= axes[1] ,data = df_mpg, x = 'model_year', y = 'mpg')

# %% [markdown]
# ### 10. Using data form question #1, create a box plot that shows relationship between 'cylinders' and 'horsepower'.

# %%
sns.boxplot(data = df_mpg, x = "cylinders", y = "horsepower")

# %% [markdown]
# ### 11. Using data form question #1, create a bar chart that shows relationship between 'cylinders' and 'horsepower'.

# %%
sns.barplot(data = df_mpg, x = "cylinders", y = "horsepower")

# %% [markdown]
# ### 12. Using data form question #1, create a horizontal bar chart that shows relationship between 'cylinders' and 'horsepower'.

# %%
sns.barplot(data = df_mpg, x = "horsepower", y = "cylinders", orient = "h")

# %% [markdown]
# ### 13. Using data form question #1, create a count plot for 'model_year'.

# %%
sns.countplot(df_mpg.model_year)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### 14. Show plots from question #10 to #13 in 2 rows and 2 columns.

# %%
fig, axes = plt.subplots(2,2, figsize = (15,10))
sns.boxplot(ax = axes[0,0], data = df_mpg, x = "cylinders", y = "horsepower")
sns.barplot(ax = axes[0,1], data = df_mpg, x = "cylinders", y = "horsepower")
sns.barplot(ax = axes[1,0], data = df_mpg, x = "horsepower", y = "cylinders", orient = "h")
sns.countplot(ax = axes[1,1], data = df_mpg, x = 'model_year')

# %% [markdown]
# ### 15. Using data form question #1, create a violen plot for 'weight'.

# %%
sns.violinplot(x = df_mpg.weight)

# %% [markdown]
# ### 16. Using data form question #1, create a heap map that show the correlation between all columns.

# %%
sns.heatmap(df_mpg.corr(), cmap="YlGnBu", annot = True)

# %% [markdown]
# ### 17. Using data form question #1, create a scatter plot with a regression line that shows the relationship between 'year_model' and 'mpg'.

# %%
sns.regplot(data = df_mpg, x = "model_year", y = "mpg")

# %% [markdown]
# ### 18. Using 'titanic' data in Seaborn, create a few charts and write a short essay (>50 words) to answer the queston "What kind of passengers that survived the accident ?" [3 points]

# %%
df_titanic = sns.load_dataset('titanic')
display(df_titanic.head(5))
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.barplot(data = df_titanic, x = 'sex', y = "survived")

# %% [markdown]
# # "What kind of passengers that survived the accident ?
# => Based on the graph above, most percentage of people who survived the accident is female.

# %% [markdown]
# ### 19. Using 'tips' data in Seaborn, create a few charts and write a short essay (>50 words) to answer the queston "What kind of customers that give the highest tips ?" [3 points]

# %%
df_tips = sns.load_dataset("tips")
display(df_tips.head(5))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig, axes = plt.subplots(1,3, figsize = (18,5))
sns.barplot(ax = axes[0], data = df_tips, x = 'sex', y = "tip") 
sns.barplot(ax = axes[1], data = df_tips, x = 'size', y = "tip") 
sns.barplot(ax = axes[2], data = df_tips, x = 'smoker', y = "tip")

# %% [markdown]
# # "What kind of customers that give the highest tips ?"
# => Based on the above graph, we can say that most of customer that give the highest tips is male customer, and it also depend on the amount of customer who went to that restaurants. Like you see in the graph, when the size of customer increase, the higher tips also increase as well.

# %% [markdown]
# ### 20. Using 'car_crashes' data in Seaborn, create a plot to answer the question below.
# ### What are the top 3 states (use 'abbrev') that has the higest number of car crash (use 'total') ? [2 points]
# #### Note : you must crate a plot that can be easily identify the 3 states.

# %%
df_car_crashes = sns.load_dataset("car_crashes")
display(df_car_crashes.head(5))
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
plt.figure(figsize=(15,5))
sns.barplot(data = df_car_crashes, x = "abbrev", y = "total")

# %% [markdown]
# # Answer the question
# => The top 3 states that has the higest number of car crash are:
# 1. ND
# 2. SC
# 3. WV

# %% [markdown]
# ### 21. Using 'diamonds' data in Seaborn, create a few charts and write a short essay (>50 words) to answer the queston "What kind of diamonds that are the most expensive ?" [3 points]

# %%
df_diamonds = sns.load_dataset("diamonds")
display(df_diamonds.head(5))
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
fig, axes = plt.subplots(1,2, figsize = (18,5))
sns.barplot(ax = axes[0], data = df_diamonds, x = 'clarity', y = "price") 
sns.barplot(ax = axes[1], data = df_diamonds, x = 'color', y = "price")

# %% [markdown]
# # "What kind of diamonds that are the most expensive ?"
# => Here are two different graph that can help us to identify which types of diamonds are the most expensive. If you look at both graphs above you will see that the types "Sl1"clarity have the highest price compare to other types clarity of diamond and most of it is color "J" as for the second graph.

# %% [markdown]
# ### 22. Using 'iris' data in Seaborn, create 2 charts to answer the queston "What 'species' that has the highest 'sepal_length' and 'petal_length' on average ?" [2 points]

# %%
df_iris = sns.load_dataset("iris")
df_iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
fig, axes = plt.subplots(1,2, figsize = (15,5))
sns.barplot(ax = axes[0], data = df_iris, x = "species", y = "sepal_length")
sns.barplot(ax = axes[1], data = df_iris, x = "species", y = "petal_length")

# %% [markdown]
# # "What 'species' that has the highest 'sepal_length' and 'petal_length' on average ?"
# 1. The species that has the highest "sepal_length" is Virginica.
# 2. The species that has the highest "petal_length" is Virginica.
